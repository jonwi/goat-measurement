# %%
from ultralytics import YOLO

model = YOLO("best.pt")
model.export(format="tfjs")

# %%
import utils

model = YOLO("best.onnx", task="segment")
results = model.predict("datasets/zweite_messung/24_image.png")
for result in results:
    utils.plot(result)
